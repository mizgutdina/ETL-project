# %%
import pandas as pd
import numpy as np

# %%
#Extracting data from Starbucks data csv
df = pd.read_csv('Resources/Starbucks_data.csv', dtype={'Postcode': 'str'})  
df.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# ...

# %%
#Verify the number of rows
total_rows = df['Brand'].count
total_rows
# Out:
# <bound method Series.count of 0        Starbucks
# 1        Starbucks
# 2        Starbucks
# 3        Starbucks
# 4        Starbucks
#            ...
# 25595    Starbucks
# 25596    Starbucks
# 25597    Starbucks
# 25598    Starbucks
# 25599    Starbucks
# Name: Brand, Length: 25600, dtype: object>

# %%
#s.str.zfill(3)

# %%
#
US_df = df.loc[df['Country'] == 'US']
US_df
# Out:
#            Brand  Store Number                        Store Name  \
# 11964  Starbucks   3513-125945           Safeway-Anchorage #1809
# 11965  Starbucks   74352-84449           Safeway-Anchorage #2628
# 11966  Starbucks  12449-152385         Safeway - Anchorage #1813
# 11967  Starbucks  24936-233524          100th & C St - Anchorage
# 11968  Starbucks    8973-85630              Old Seward & Diamond
# ...          ...           ...                               ...
# 25567  Starbucks   74385-87621             Safeway-Laramie #2466
# 25568  Starbucks   73320-24375          Ridley's - Laramie #1131
# 25569  Starbucks  22425-219024            Laramie - Grand & 30th
# 25570  Starbucks  10849-103163      I-80 & Dewar Dr-Rock Springs
# 25571  Starbucks  10769-102454  Coffeen & Brundage Lane-Sheridan
#
#       Ownership Type                                     Street Address  \
# 11964       Licensed                               5600 Debarr Rd Ste 9
# ...

# %%
US_df['Postcode'] = US_df['Postcode'].dropna()
US_df
# Out:
# /Users/medinai/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            Brand  Store Number                        Store Name  \
# 11964  Starbucks   3513-125945           Safeway-Anchorage #1809
# 11965  Starbucks   74352-84449           Safeway-Anchorage #2628
# 11966  Starbucks  12449-152385         Safeway - Anchorage #1813
# 11967  Starbucks  24936-233524          100th & C St - Anchorage
# 11968  Starbucks    8973-85630              Old Seward & Diamond
# ...          ...           ...                               ...
# 25567  Starbucks   74385-87621             Safeway-Laramie #2466
# ...

# %%
#Keep 5 digit Postalcode
#Condition: IF Postalcode > 5 digit, THEN chop last 4 digits, ELSE leave it alone
US_df['five_digit_zip'] = np.where(US_df['Postcode'].str.len() == 9, 
                                     US_df['Postcode'].str[:5],
                                     US_df['Postcode'])
print(US_df)
# Out:
#            Brand  Store Number                        Store Name  \
# 11964  Starbucks   3513-125945           Safeway-Anchorage #1809
# 11965  Starbucks   74352-84449           Safeway-Anchorage #2628
# 11966  Starbucks  12449-152385         Safeway - Anchorage #1813
# 11967  Starbucks  24936-233524          100th & C St - Anchorage
# 11968  Starbucks    8973-85630              Old Seward & Diamond
# ...          ...           ...                               ...
# 25567  Starbucks   74385-87621             Safeway-Laramie #2466
# 25568  Starbucks   73320-24375          Ridley's - Laramie #1131
# 25569  Starbucks  22425-219024            Laramie - Grand & 30th
# 25570  Starbucks  10849-103163      I-80 & Dewar Dr-Rock Springs
# 25571  Starbucks  10769-102454  Coffeen & Brundage Lane-Sheridan
#
#       Ownership Type                                     Street Address  \
# 11964       Licensed                               5600 Debarr Rd Ste 9
# ...

# %%
US_df['five_digit_zip'] = np.where(US_df['five_digit_zip'].str.len() == 8, 
                                     US_df['five_digit_zip'].str[:4],
                                     US_df['five_digit_zip'])
print(US_df)
# Out:
#            Brand  Store Number                        Store Name  \
# 11964  Starbucks   3513-125945           Safeway-Anchorage #1809
# 11965  Starbucks   74352-84449           Safeway-Anchorage #2628
# 11966  Starbucks  12449-152385         Safeway - Anchorage #1813
# 11967  Starbucks  24936-233524          100th & C St - Anchorage
# 11968  Starbucks    8973-85630              Old Seward & Diamond
# ...          ...           ...                               ...
# 25567  Starbucks   74385-87621             Safeway-Laramie #2466
# 25568  Starbucks   73320-24375          Ridley's - Laramie #1131
# 25569  Starbucks  22425-219024            Laramie - Grand & 30th
# 25570  Starbucks  10849-103163      I-80 & Dewar Dr-Rock Springs
# 25571  Starbucks  10769-102454  Coffeen & Brundage Lane-Sheridan
#
#       Ownership Type                                     Street Address  \
# 11964       Licensed                               5600 Debarr Rd Ste 9
# ...

# %%
# US_df['five_digit_zip'] = np.where(US_df['Postcode'].str.len() == 7, 
#                                      US_df['Postcode'].str[:3],
#                                      US_df['Postcode'])
# print(US_df)

# %%
# US_df['five_digit_zip'].str.zfill(5)
# US_df['five_digit_zip']
# US_df['five_digit_zip'].dtype()

# %%
US_df['five_digit_zip'] = US_df['five_digit_zip'].str.zfill(5)
#US_df['five_digit_zip'] = US_df['five_digit_zip'].apply(lambda x: x.zfill(5))
US_df['five_digit_zip']
# Out:
# /Users/medinai/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 11964    99504
# 11965    99507
# 11966    99515
# 11967    99515
# 11968    99515
#          ...
# 25567    82072
# 25568    82070
# 25569    82070
# 25570    82901
# 25571    82801
# Name: five_digit_zip, Length: 13608, dtype: object

# %%
US_clean_df = US_df[['Store Name','Street Address','City','State/Province','Country', 'five_digit_zip', 'Phone Number',
                    'Longitude','Latitude']]
US_clean_df
# Out:
#                              Store Name  \
# 11964           Safeway-Anchorage #1809
# 11965           Safeway-Anchorage #2628
# 11966         Safeway - Anchorage #1813
# 11967          100th & C St - Anchorage
# 11968              Old Seward & Diamond
# ...                                 ...
# 25567             Safeway-Laramie #2466
# 25568          Ridley's - Laramie #1131
# 25569            Laramie - Grand & 30th
# 25570      I-80 & Dewar Dr-Rock Springs
# 25571  Coffeen & Brundage Lane-Sheridan
#
#                                           Street Address          City  \
# 11964                               5600 Debarr Rd Ste 9     Anchorage
# 11965                                     1725 Abbott Rd     Anchorage
# 11966                                    1501 Huffman Rd     Anchorage
# 11967  320 W. 100th Ave, 100, Southgate Shopping Ctr ...     Anchorage
# 11968                                 1005 E Dimond Blvd     Anchorage
# ...

# %%
US_clean_df.reset_index(drop=True, inplace=True)

print(US_clean_df)
# Out:
#                              Store Name  \
# 0               Safeway-Anchorage #1809
# 1               Safeway-Anchorage #2628
# 2             Safeway - Anchorage #1813
# 3              100th & C St - Anchorage
# 4                  Old Seward & Diamond
# ...                                 ...
# 13603             Safeway-Laramie #2466
# 13604          Ridley's - Laramie #1131
# 13605            Laramie - Grand & 30th
# 13606      I-80 & Dewar Dr-Rock Springs
# 13607  Coffeen & Brundage Lane-Sheridan
#
#                                           Street Address          City  \
# 0                                   5600 Debarr Rd Ste 9     Anchorage
# 1                                         1725 Abbott Rd     Anchorage
# 2                                        1501 Huffman Rd     Anchorage
# 3      320 W. 100th Ave, 100, Southgate Shopping Ctr ...     Anchorage
# 4                                     1005 E Dimond Blvd     Anchorage
# ...

# %%
US_test_clean_df = US_clean_df.loc[US_clean_df['State/Province']=='MA'] 
#US_df = df.loc[df['Country'] == 'US']
US_test_clean_df
# Out:
#                           Store Name  \
# 6583          Target Abington T-2173
# 6584           Acton, Kelly's Corner
# 6585     Amherst, North Pleasant St.
# 6586                Main St. Andover
# 6587                       Arlington
# ...                              ...
# 6851            Target Woburn T-1266
# 6852      Woburn, West Cummings Park
# 6853   West Boylston St. & Grove St.
# 6854         Target Worcester T-1348
# 6855  Worcester, East Central Street
#
#                                   Street Address       City State/Province  \
# 6583                              375 Centre Ave   Abington             MA
# 6584                      411 Massachusettes Ave      Acton             MA
# 6585                    71 North Pleasant Street    Amherst             MA
# 6586                              14 Main Street    Andover             MA
# 6587                                327 Broadway  Arlington             MA
# ...

# %%
US_test_clean_df = US_clean_df.loc[US_clean_df['Store Name']=='PA Valley Forge Travel Plaza'] 
US_test_clean_df
# Out:
#                          Store Name                      Street Address  \
# 10651  PA Valley Forge Travel Plaza  Exit 326 Eastbound, Milepost 324.6
#
#                City State/Province Country five_digit_zip Phone Number  \
# 10651  Southeastern             PA      US          19399   6109758940
#
#        Longitude  Latitude
# 10651     -75.44     40.08

# %%
US_clean_df
# Out:
#                              Store Name  \
# 0               Safeway-Anchorage #1809
# 1               Safeway-Anchorage #2628
# 2             Safeway - Anchorage #1813
# 3              100th & C St - Anchorage
# 4                  Old Seward & Diamond
# ...                                 ...
# 13603             Safeway-Laramie #2466
# 13604          Ridley's - Laramie #1131
# 13605            Laramie - Grand & 30th
# 13606      I-80 & Dewar Dr-Rock Springs
# 13607  Coffeen & Brundage Lane-Sheridan
#
#                                           Street Address          City  \
# 0                                   5600 Debarr Rd Ste 9     Anchorage
# 1                                         1725 Abbott Rd     Anchorage
# 2                                        1501 Huffman Rd     Anchorage
# 3      320 W. 100th Ave, 100, Southgate Shopping Ctr ...     Anchorage
# 4                                     1005 E Dimond Blvd     Anchorage
# ...
